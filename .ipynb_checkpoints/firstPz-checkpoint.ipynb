# %% [markdown]
# ***Практическаая Работа №1***

# %%
3+2
# Out:
# 5

# %%
a = 5
b = 7
print(a + b)
# Out:
# 12

# %%
n = 7 
for i in range(n):
    print(i*10)
# Out:
# 0
# 10
# 20
# 30
# 40
# 50
# 60

# %%
i = 0
while True:
    i += 1
    if i > 5:
        break
    print("Test while")
# Out:
# Test while
# Test while
# Test while
# Test while
# Test while

# %%
from matplotlib import pylab as plt
# %matplotlib inline

# %%
x = [i for i in  range(50)]
y = [i**2 for i in range(50)]
plt.plot(x,y)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %env TEST = 5
# Out:
# env: TEST=5

# %%
# %%time
import time
for i in range(50):
    time.sleep(0.1)
# Out:
# CPU times: total: 0 ns
# Wall time: 5.01 s

# %%
# %timeit x = [(i**10) for i in range(10)]
# Out:
# 765 ns ± 56.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("График синусоиды")
plt.show()

# %% [markdown]
# Список маркированный
#  - Пункт 1
#  - Пункт 2
#  - Пункт 3

# %% [markdown]
# Список нумерованный
# 1. Элемент списка
# 2. Элемент списка
# 3. Элемент списка

# %% [markdown]
# Формула для производной функции логарифма:
#
# $
# \frac{d}{dx} \ln(x) = \frac{1}{x}
# $

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('Image/1.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
a = input("Введите Ваше имя: ")
print("Привет, ", a, "Добро пожаловать в JupyterLab / Google Colab!")
# Out:
# Введите Ваше имя:  Глеб
# Привет,  Глеб Добро пожаловать в JupyterLab / Google Colab!

# %% [markdown]
# ***Работа с файлами***

# %%
import os
with open("test.txt", "w", encoding="utf-8") as f:
    f.write("Первая строка\n")
    f.write("Вторая строка\n")

with open("test.txt", "r", encoding="utf-8") as f:
    content = f.read()
    print("Содержимое файла:\n", content)
print("Файл существует:", os.path.exists("test.txt"))
os.remove("test.txt")
print("Файл удален.")
# Out:
# Содержимое файла:
#  Первая строка
# Вторая строка
#
# Файл существует: True
# Файл удален.

# %% [markdown]
# ***Магические команды Jupyter***

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %%time
import time
for i in range(50):
    time.sleep(0.1)
# Out:
# CPU times: total: 0 ns
# Wall time: 5.01 s

# %%
# %%writefile test_script.py
for i in range(3):
print(f"Итерация {i}")
# Выполнение скрипта
!python test_script.py
# Измерение времени выполнения
%time sum(range(1000000))
# Out:
# Writing test_script.py

# %%
# %ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 94C0-A29D
#
#  Directory of C:\Users\Kutep\Desktop\??????\2 ????\2 ???????\AI
#
# 14.03.2025  14:23    <DIR>          .
# 14.02.2025  15:23    <DIR>          ..
# 14.03.2025  14:07    <DIR>          .ipynb_checkpoints
# 14.03.2025  14:22           184ÿ861 1 ????????????.ipynb
# 28.02.2025  13:23               956 2 ????????????.ipynb
# 28.02.2025  13:59           123ÿ453 3 ????????????.ipynb
# 14.03.2025  13:20               617 4 ????????????.ipynb
# 14.03.2025  13:37    <DIR>          Image
# 14.03.2025  14:23               200 test_script.py
# 14.02.2025  14:24                18 ????.txt
#                6 File(s)        310ÿ105 bytes
#                4 Dir(s)  286ÿ034ÿ706ÿ432 bytes free

# %% [markdown]
# ***Взаимодействие с оболочкой системы***

# %%
# !dir
# !where python
# !mkdir new_folder 
# !rmdir new_folder
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 94C0-A29D
#
#  Directory of C:\Users\Kutep\Desktop\??????\2 ????\2 ???????\AI
#
# 14.03.2025  14:37    <DIR>          .
# 14.02.2025  15:23    <DIR>          ..
# 14.03.2025  14:27    <DIR>          #
# 14.03.2025  14:07    <DIR>          .ipynb_checkpoints
# 14.03.2025  14:36           194ÿ866 1 ????????????.ipynb
# 28.02.2025  13:23               956 2 ????????????.ipynb
# 28.02.2025  13:59           123ÿ453 3 ????????????.ipynb
# 14.03.2025  13:20               617 4 ????????????.ipynb
# 14.03.2025  13:37    <DIR>          Image
# 14.03.2025  14:26    <DIR>          test_folder
# 14.03.2025  14:23               200 test_script.py
# 14.02.2025  14:24                18 ????.txt
#                6 File(s)        320ÿ110 bytes
#                6 Dir(s)  286ÿ049ÿ988ÿ608 bytes free
# C:\Users\Kutep\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\Kutep\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
from google.colab import drive
# Подключение Google Drive
drive.mount('/content/drive')
# Запись текста в файл
file_path = "/content/drive/MyDrive/my_text_file.txt"
with open(file_path, "w") as f:
    f.write("Это тестовый файл, сохраненный в Google Drive.\n")
    f.write("Вторая строка текста.")
print("Файл успешно сохранен в Google Drive.")
# Чтение файла
with open(file_path, "r") as f:
    content = f.read()
    print("Содержимое файла:\n", content)
# Создание CSV вручную
students = [
    ["Иванов И.И.", 20, "ИВТ-101"],
    ["Петров П.П.", 22, "ИВТ-102"],
    ["Сидорова А.А.", 21, "ИВТ-103"]
]
csv_path = "/content/drive/MyDrive/students.csv"
with open(csv_path, "w") as f:
    for student in students:
        f.write(",".join(map(str, student)) + "\n")
print("Файл students.csv успешно сохранен в Google Drive.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from google.colab import drive
#       2 # Подключение Google Drive
#       3 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'
